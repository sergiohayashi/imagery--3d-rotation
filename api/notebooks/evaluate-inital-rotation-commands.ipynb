# %%
d = {
    "0-3-3-1-5": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:10,up:10,down:30,down:10,rotate:ccw:10,rotate:ccw:10,down:10"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "left:45,rotate:cw:10,rotate:cw:10,rotate:cw:10,rotate:cw:10,down:10,down:10"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "up:45,up:45,up:45,right:15,right:15,right:15,right:15,rotate:cw:15,left:15,rotate:cw:10"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "up:180"
        }
    },
    "1-2-3-1-4": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,right:10,rotate:ccw:60,down:30,right:20"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "left:50,down:100,left:15,rotate:cw:10"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ]
            ],
            "rotation": "right:180,down:75"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ]
            ],
            "rotation": "up:180"
        }
    },
    "2-3-3-1-4": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,down:50,rotate:ccw:30,left:10"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ]
            ],
            "rotation": "down:180"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,down:50,rotate:ccw:30,left:10,rotate:cw:180,down:80,right:30,rotate:ccw:20,down:20,left:20"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    1,
                    2
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    1,
                    2
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:30,rotate:cw:20"
        }
    },
    "3-3-2-1-4": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:30,down:40"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    1,
                    2
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    1,
                    2
                ]
            ],
            "rotation": "right:180,down:70"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "left:0"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:cw:180,down:75"
        }
    },
    "4-2-3-1-4": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:130,down:60,rotate:ccw:15,left:30"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    1,
                    2
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    1,
                    2
                ]
            ],
            "rotation": "rotate:cw:120"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:180,down:75"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "down:45,rotate:ccw:135,left:40,down:30"
        }
    },
    "5-2-3-1-5": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:100,down:60,rotate:ccw:45,left:30"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:115,up:15,rotate:ccw:5,down:10"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:90,right:90,rotate:cw:30,right:15"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,down:45,rotate:ccw:30"
        }
    },
    "6-3-3-1-5": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:35,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:35,down:45,rotate:cw:90,right:90,rotate:ccw:30"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:35,down:45,rotate:cw:90,right:90,rotate:ccw:30,left:90,rotate:cw:25"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    1,
                    2
                ]
            ],
            "rotation": "rotate:ccw:180,down:80"
        }
    },
    "7-3-3-1-8": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:35,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:90,right:45,rotate:ccw:45,right:45,rotate:ccw:5,right:15,down:30"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "left:0"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:90,right:45,rotate:cw:45,left:45,down:30,right:15"
        }
    },
    "8-3-3-1-7": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:60,right:90,rotate:cw:35,down:30"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "left:90,rotate:cw:45,down:45"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        }
    },
    "9-3-3-1-6": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ]
            ],
            "rotation": "left:0"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ]
            ],
            "rotation": "left:90,rotate:cw:45,down:45"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        }
    },
    "10-2-3-1-4": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "left:90,rotate:cw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:90,rotate:cw:60,left:45,rotate:ccw:45,left:45,rotate:ccw:10,down:40"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,up:90,rotate:ccw:90,down:45,right:45,up:15,right:15"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "down:90,rotate:cw:50,left:20,rotate:cw:10,down:10"
        }
    },
    "11-3-3-1-5": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:35,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:35,down:45,down:180"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:35,down:45,left:90,down:90,right:45,up:45"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ]
            ],
            "rotation": "down:90,right:60,rotate:ccw:30,down:60,left:45"
        }
    },
    "12-3-3-1-5": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:65,down:45,right:100,rotate:ccw:10,down:30,left:10"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "down:180"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "left:0"
        }
    },
    "13-3-3-1-5": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:35,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:100,left:30,down:45,right:140,down:30,rotate:ccw:10"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:180,down:80"
        },
        "C": {
            "bounds": [
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "left:90,rotate:cw:30,down:45"
        }
    },
    "14-3-3-1-6": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:40,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "up:180"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "down:70,rotate:ccw:45,right:45,rotate:ccw:10,down:15"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:40,down:45"
        }
    },
    "15-3-3-1-6": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:40,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:40,down:45"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:cw:120,right:180,down:70"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "left:0"
        }
    },
    "16-3-3-1-6": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:30,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "down:70,rotate:ccw:50,right:30,down:25"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "down:60,left:45,rotate:ccw:15"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:180,down:80"
        }
    },
    "17-3-3-1-6": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45,rotate:cw:15"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "left:90,rotate:cw:45,down:45"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "down:60,rotate:ccw:120,left:45,rotate:ccw:15,down:30"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "down:60,rotate:ccw:70,right:45,rotate:cw:15,down:15"
        }
    },
    "18-3-3-1-4": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ]
            ],
            "rotation": "up:120,rotate:cw:45,right:45,down:30"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "left:90,rotate:cw:45,down:45"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "up:120,rotate:ccw:45,right:140,down:40"
        }
    },
    "19-2-3-1-5": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "left:90,rotate:cw:45,down:45"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "left:90,rotate:cw:45,down:45"
        }
    },
    "20-2-3-1-5": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "left:90,rotate:cw:45,down:45"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "down:60,rotate:cw:90,right:60,rotate:cw:15"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "left:90,rotate:cw:45,down:45"
        }
    },
    "21-2-3-1-5": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "down:60,rotate:ccw:135,left:45,down:45"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "down:60,rotate:ccw:135,left:45,down:45"
        }
    },
    "22-2-4-1-5": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:180,down:90"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "up:120,rotate:cw:40,right:40,down:30"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "left:90,rotate:cw:45,down:45"
        }
    },
    "23-2-4-1-4": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "up:120,right:45"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "left:0"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "up:180"
        }
    },
    "24-2-4-1-7": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "down:60,rotate:ccw:50,right:45,down:30"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "down:60,rotate:ccw:45,down:180,right:45,down:30"
        }
    },
    "25-2-4-1-6": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "left:90,rotate:cw:45,down:45"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "up:180"
        }
    },
    "26-2-4-1-8": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "left:90,down:45,rotate:cw:30,right:30"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:30,down:45"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "left:0"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "left:90,down:45,rotate:cw:30,right:30"
        }
    },
    "27-2-4-1-6": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,up:90,rotate:ccw:90,right:45,rotate:cw:30,down:10"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "down:45,right:90,rotate:cw:10,down:90,left:45,rotate:cw:30"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "left:180,down:80"
        }
    },
    "28-2-3-1-4": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,down:45,rotate:ccw:30,left:20"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:120"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:cw:180,down:75"
        }
    },
    "29-2-4-1-5": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:120,right:60,up:10"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:180,down:70"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:120"
        }
    },
    "30-3-4-1-6": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:130,up:30"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "left:0"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    1,
                    2
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:60,down:60,right:90,rotate:ccw:25,down:45"
        }
    },
    "31-3-4-1-7": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "down:150,rotate:ccw:90,left:45,rotate:cw:30"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:90,right:45,rotate:ccw:30,left:45,down:20,right:10,rotate:ccw:15"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:cw:180,down:80"
        }
    },
    "32-3-4-1-7": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:40,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:35,down:45"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "up:180"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "down:180,right:180,down:70"
        }
    },
    "33-3-4-1-6": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:35,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "left:180,down:90"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:35,down:45"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "down:180"
        }
    },
    "34-3-4-1-9": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "left:0"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:120"
        }
    },
    "35-3-3-1-7": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:180,down:80"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "left:90,rotate:cw:45,down:45"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "up:180,down:70,right:60,up:20,rotate:cw:10,down:10"
        }
    },
    "36-3-4-1-7": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "left:0"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:120"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "up:90,right:45,up:10,right:10,up:10"
        }
    },
    "37-3-4-1-7": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "up:120,right:60"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "up:180"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        }
    },
    "38-3-4-1-7": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "rotate:ccw:120"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    3,
                    4,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    3,
                    4,
                    0,
                    1
                ]
            ],
            "rotation": "right:130,up:30"
        }
    },
    "39-3-3-1-6": {
        "original": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "A": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "left:0"
        },
        "B": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    2,
                    3,
                    0,
                    1
                ]
            ],
            "rotation": "right:90,rotate:ccw:45,down:45"
        },
        "C": {
            "bounds": [
                [
                    0,
                    1,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    0,
                    1,
                    2,
                    3,
                    0,
                    1
                ],
                [
                    1,
                    2,
                    1,
                    2,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    0,
                    1,
                    0,
                    1
                ],
                [
                    2,
                    3,
                    1,
                    2,
                    0,
                    1
                ]
            ],
            "rotation": "down:70,rotate:ccw:60,right:45,down:10"
        }
    }
}

# %%
d
# Out:
# {'0-3-3-1-5': {'original': {'bounds': [[0, 1, 2, 3, 0, 1],
#     [1, 2, 0, 1, 0, 1],
#     [1, 2, 1, 2, 0, 1],
#     [1, 2, 2, 3, 0, 1],
#     [2, 3, 1, 2, 0, 1]],
#    'rotation': 'right:90,rotate:ccw:10,up:10,down:30,down:10,rotate:ccw:10,rotate:ccw:10,down:10'},
#   'A': {'bounds': [[0, 1, 0, 1, 0, 1],
#     [1, 2, 0, 1, 0, 1],
#     [1, 2, 1, 2, 0, 1],
#     [2, 3, 1, 2, 0, 1]],
#    'rotation': 'left:45,rotate:cw:10,rotate:cw:10,rotate:cw:10,rotate:cw:10,down:10,down:10'},
#   'B': {'bounds': [[0, 1, 2, 3, 0, 1],
#     [1, 2, 0, 1, 0, 1],
#     [1, 2, 1, 2, 0, 1],
#     [1, 2, 2, 3, 0, 1],
#     [2, 3, 1, 2, 0, 1]],
#    'rotation': 'up:45,up:45,up:45,right:15,right:15,right:15,right:15,rotate:cw:15,left:15,rotate:cw:10'},
#   'C': {'bounds': [[0, 1, 2, 3, 0, 1],
#     [1, 2, 0, 1, 0, 1],
#     [1, 2, 1, 2, 0, 1],
#     [1, 2, 2, 3, 0, 1],
#     [2, 3, 1, 2, 0, 1]],
#    'rotation': 'up:180'}},
#  '1-2-3-1-4': {'original': {'bounds': [[0, 1, 0, 1, 0, 1],
# ...

# %%
keys = list(d.keys())

# %%
keys[0]
# Out:
# '0-3-3-1-5'

# %%
d[keys[0]]
# Out:
# {'original': {'bounds': [[0, 1, 2, 3, 0, 1],
#    [1, 2, 0, 1, 0, 1],
#    [1, 2, 1, 2, 0, 1],
#    [1, 2, 2, 3, 0, 1],
#    [2, 3, 1, 2, 0, 1]],
#   'rotation': 'right:90,rotate:ccw:10,up:10,down:30,down:10,rotate:ccw:10,rotate:ccw:10,down:10'},
#  'A': {'bounds': [[0, 1, 0, 1, 0, 1],
#    [1, 2, 0, 1, 0, 1],
#    [1, 2, 1, 2, 0, 1],
#    [2, 3, 1, 2, 0, 1]],
#   'rotation': 'left:45,rotate:cw:10,rotate:cw:10,rotate:cw:10,rotate:cw:10,down:10,down:10'},
#  'B': {'bounds': [[0, 1, 2, 3, 0, 1],
#    [1, 2, 0, 1, 0, 1],
#    [1, 2, 1, 2, 0, 1],
#    [1, 2, 2, 3, 0, 1],
#    [2, 3, 1, 2, 0, 1]],
#   'rotation': 'up:45,up:45,up:45,right:15,right:15,right:15,right:15,rotate:cw:15,left:15,rotate:cw:10'},
#  'C': {'bounds': [[0, 1, 2, 3, 0, 1],
#    [1, 2, 0, 1, 0, 1],
#    [1, 2, 1, 2, 0, 1],
#    [1, 2, 2, 3, 0, 1],
#    [2, 3, 1, 2, 0, 1]],
#   'rotation': 'up:180'}}

# %%
k = keys[0]

# %%
d[k].keys()
# Out:
# dict_keys(['original', 'A', 'B', 'C'])

# %%
rotations = []
for p,v in d.items():
    for alt,data in v.items():
        rotations.append(data['rotation'])

# %%
len(rotations)
# Out:
# 160

# %%
data = [len(r.split(',')) for r in rotations]

# %%
'a,b'.split(',')
# Out:
# ['a', 'b']

# %%
import statistics

# %%
# Median
median = statistics.median(data)

# Variance (sample variance)
variance = statistics.variance(data)

# Standard deviation (sample)
std_dev = statistics.stdev(data)

print("Median:", median)
print("Variance:", variance)
print("Standard deviation:", std_dev)
# Out:
# Median: 3.0
# Variance: 3.1537342767295597
# Standard deviation: 1.7758756366169226

# %%
min(data), max(data)
# Out:
# (1, 10)
